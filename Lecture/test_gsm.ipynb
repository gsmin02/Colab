# %% [markdown]
# # 연습 제목
#
# **자기이름: 구승민**
#
# [링크 텍스트](https://lms.induk.ac.kr)
#
# 1.   항목 추가
# 2.   항목 추가
#
# *   항목 추가
# ---
# *   항목 추가
#
# ✈

# %% [markdown]
# # 두번째 텍스트
# 구승민연습

# %%
print("테스트")
# Out:
# 테스트
