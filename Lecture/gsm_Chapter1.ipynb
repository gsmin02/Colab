# %% [markdown]
# # 첫번째 문제
#
# *1.   두 수의 합을 구하는 코드를 작성하시오. 이 텍스트를 이탤릭체로 변경하시오.*

# %%
gsm1 = 3
gsm2 = 5
print(gsm1-gsm2)
# Out:
# -2

# %%
gsm1 = 3
gsm2 = 5
print(gsm1 + gsm2)
# Out:
# 8

# %% [markdown]
# # 두 수의 뺄셈을 구하는 코드
