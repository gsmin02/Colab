# %% [markdown]
# [코드 gsm 4-9] beautifulsoup 설치

# %%
# !pip install bs4

# %% [markdown]
# [코드 gsm 4-10]  urllib.request를 이용한 코드 접근

# %%
import urllib.request

nateUrl = "https://www.nate.com/"
htmlObject = urllib.request.urlopen(nateUrl)
html = htmlObject.read()

print(html)
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t\r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta name="msapplication-starturl" content="//www.nate.com/" />\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta name="nate:title" content="" />\r\n<meta name="nate:description" content="\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8 \xec\x9d\xb4\xec\x8a\x88UP" />\r\n<meta name="nate:site_name" content="\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8 \xed\x99\x88" />\r\n<meta name="nate:url" content="https://www.nate.com/" />\r\n<meta name="nate:image" content="" />\r\n<meta name="description" content="\xec\x83\x88\xeb\xa1\x9c\xec\x9b\x8c\xec\xa7\x84 \xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xb9\xec\x8b\xa0\xec\x9d\x98 \xec\x98\xa4\xeb\x8a\x98\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\r\n<meta name="viewport" content="width=device-width, initial-scale=1" />\r\n<meta property="og:title" co
# ...

# %% [markdown]
# [코드 gsm 4-11] beautifulsoup 불러오기

# %%
import urllib.request
import bs4
nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
bsObject = bs4.BeautifulSoup(htmlObject, 'html.parser')
print(bsObject)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>네이트</title>
# ...

# %% [markdown]
# [코드 gsm 4-12] files 라이브러리

# %%
from google.colab import files
f = files.upload()
# Out:
#      <input type="file" id="files-8db8df91-8670-4188-84b1-43eff09fdeab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8db8df91-8670-4188-84b1-43eff09fdeab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# [코드 gsm 4-13] 태그 출력

# %%
import bs4
webPage = open('gsm_sample2.html', 'rt', encoding='utf8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
print(bsObject)
# Out:
# <html>
# <head>
# </head>
# <body>
# <div> 요기를 클릭하세요 </div>
# <ul>
# <li> 구승민 </li>
# <li> 9월달 </li>
# <li> 데이터 분석 </li>
# </ul>
# </body>
# </html>

# %% [markdown]
# [코드 gsm 4-14] \<div\> 태그의 접근

# %%
import bs4
webPage = open('gsm_sample2.html', 'rt', encoding='utf8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
tag_div = bsObject.find('div')
print(tag_div)
# Out:
# <div> 요기를 클릭하세요 </div>

# %% [markdown]
# [코드 gsm 4-15] 여러 건의 데이터 추출

# %%
import bs4

webPage = open('gsm_sample2.html', 'rt', encoding='utf8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_ul= bsObject.find('ul')
print(tag_ul)
print()

tag_li= bsObject.find('li')
print(tag_li)
print()

tag_li_all= bsObject.findAll('li')
print(tag_li_all)
# Out:
# <ul>
# <li> 구승민 </li>
# <li> 9월달 </li>
# <li> 데이터 분석 </li>
# </ul>
#
# <li> 구승민 </li>
#
# [<li> 구승민 </li>, <li> 9월달 </li>, <li> 데이터 분석 </li>]

# %% [markdown]
# [코드 gsm 4-16] files 라이브러리

# %%
from google.colab import files
#파일 업로드 함수 호출하기
f = files.upload( )
# Out:
#      <input type="file" id="files-4be1d990-80c7-4d28-ba66-71845b764e58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4be1d990-80c7-4d28-ba66-71845b764e58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# [코드 gsm 4-17] find()& findAll() 함수

# %%
import bs4
webPage = open('gsm_sample3.html', 'rt', encoding='utf-8').read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'id':'myId1'})
print(tag.text)

tag = bsObject.find('div', {'class':'myClass1'})
print(tag)

tag = bsObject.findAll('div', {'class':'myClass1'})
for t in tag :
  print(t.text)
# Out:
#  아기공룡
# <div class="myClass1"> 내 친구 </div>
#  내 친구
#  둘리

# %% [markdown]
# [코드 gsm 4-18] \<ul\> 및 \<li\>의 값 출력

# %%
import bs4
webPage = open('gsm_sample3.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

ul_value = bsObject.find('ul', {'class':'myClass2'})
print(ul_value)
print()

li_list = bsObject.findAll('li', {'class':'myClass3'})
print(li_list)
# Out:
# <ul class="myClass2">
# <li> 구승민 </li>
# <li> 구승민 </li>
# </ul>
#
# [<li class="myClass3"> 비기너 </li>, <li class="myClass3"> 시리즈 </li>]

# %% [markdown]
# [코드 gsm 4-19] \<a\>의 href 속성값 출력

# %%
import bs4
webPage = open('gsm_sample3.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

a_list = bsObject.findAll('a')

for aTag in a_list :
  print( aTag['href'] )
# Out:
# www.daum.net
# www.nate.com
# www.naver.com

# %% [markdown]
# [코드 gsm 4-20] \<li\> 속성값 출력

# %%
import bs4
webPage = open('gsm_sample3.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_li_all= bsObject.findAll('li')
print(len(tag_li_all))

for tag_li in tag_li_all :
  print(tag_li.text)
# Out:
# 4
#  구승민
#  구승민
#  비기너
#  시리즈

# %% [markdown]
# [코드 gsm 4-21] 원하는 문자열 출력

# %%
import bs4
import re

webPage = open('gsm_sample3.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_text= bsObject.find('li', string=re.compile('비'))
print(tag_text)
# Out:
# <li class="myClass3"> 비기너 </li>

# %% [markdown]
# [코드 gsm 4-22] 원하는 문자열 출력

# %%
import bs4
import re
webPage = open('gsm_sample3.html', 'rt', encoding='utf8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_text_all= bsObject.findAll('li', string=re.compile('비'))

for tag_li in tag_text_all :
 print(tag_li.text)
# Out:
#  비기너

# %% [markdown]
# [코드 gsm 4-23] 정보에 대한 소스 출력

# %%
import bs4
import urllib.request

libraryUrl = "https://library.induk.ac.kr/Cheetah/INDK/Index/"
htmlObject = urllib.request.urlopen(libraryUrl)

webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'logo'})
print(tag , '\n')

a_tag = tag.find("a")
print(a_tag , '\n')

href = a_tag['href']
print( href , '\n')
# Out:
# <div class="logo">
# <h2>
# <a href="https://library.induk.ac.kr/Cheetah/Home/Index">
# <img alt="인덕대학교 도서관" height="60" src="/Cheetah/Areas/INDK/content/images/Main2024/logo.png" width="300"/>
# </a>
# </h2>
# </div>
#
# <a href="https://library.induk.ac.kr/Cheetah/Home/Index">
# <img alt="인덕대학교 도서관" height="60" src="/Cheetah/Areas/INDK/content/images/Main2024/logo.png" width="300"/>
# </a>
#
# https://library.induk.ac.kr/Cheetah/Home/Index

# %% [markdown]
# [코드 gsm 4-24] files 라이브러리

# %%
from google.colab import files
#파일 업로드 함수 호출하기
f = files.upload( )
# Out:
#      <input type="file" id="files-c8e11b2c-157f-48a4-97d9-6a5a86f29dcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8e11b2c-157f-48a4-97d9-6a5a86f29dcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# [코드 gsm 4-25] \[문제1] 웹소스의 \<div>의 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을
# 쓰시오.

# %% [markdown]
# (가) : class
# (나) : myClass1

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('div', {'class':'myClass1'})

for t in tag :
 print(t.text)
# Out:
#  커피류
#  쥬스류

# %% [markdown]
# [코드 gsm 4-26] \[문제2] 웹소스의 \<div>의 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : div
# (나) : 'id'
# (다) : 'myId1'

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('div', {'id':'myId1'})
print(tag)
# Out:
# [<div id="myId1"> 맛 카페 </div>]

# %% [markdown]
# [코드 gsm 4-27] \[문제3] 웹소스의 \<ul>, \<li>의 태그 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을
# 쓰시오.

# %% [markdown]
# (가) : ul
# (나) : 'myClass2'

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('ul', {'class':'myClass2'})
print(tag)
# Out:
# [<ul class="myClass2">
# <li> 아메리카노 </li>
# <li> 카페라떼 </li>
# <li> 카푸치노 </li>
# </ul>]

# %% [markdown]
# [코드 gsm 4-28] \[문제4] 웹소스의 \<div>의 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : div

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('div')
for t in tag :
  print(t.text)
# Out:
#  맛 카페
#  커피류
#  쥬스류

# %% [markdown]
# [코드 gsm 4-29] \[문제5] 웹소스의 \<ul>, \<li>의 태그 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을
# 쓰시오.

# %% [markdown]
# (가) : li
# (나) : myClass3

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('li', {'class' : 'myClass3'})

for t in tag :
  print(t.text)
# Out:
#  오렌지쥬스
#  스무디

# %% [markdown]
# [코드 gsm 4-30] \[문제6] 웹소스의 \<a>를 모두 추출한 후 \<a>의 href 속성값인 URL을 출력하도록 파이썬 코드의 빈칸
# 답을 쓰시오.

# %% [markdown]
# (가) : a
# (나) : href

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

a_list = bsObject.find('a')

print(a_list['href'])
# Out:
# www.induk.ac.kr

# %% [markdown]
# [코드 gsm 4-31] \[문제7] 웹소스의 \<li>의 태그 정보를 이용하여 아래와 같이 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : li

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_li_all= bsObject.findAll('li')

for tag_li in tag_li_all :
  print(tag_li.text)
# Out:
#  아메리카노
#  카페라떼
#  카푸치노
#  오렌지쥬스
#  스무디

# %% [markdown]
# [코드 gsm 4-32] \[문제8] 웹소스의 \<img>태그의 값을 추출한 후, 그림파일의 이름을 출력하도록 파이썬 코드의 빈칸 답을
# 쓰시오.

# %% [markdown]
# (가) : img

# %%
import bs4
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_img= bsObject.find('img')
print( tag_img['src'])
# Out:
# gsm.jpg

# %% [markdown]
# [코드 gsm 4-33] \[문제9] 웹소스의 \<li>의 태그에 ‘카’자가 들어간 문자열이 있는 경우를 모두 검색한 후, 그들의 총 수와
# 해당하는 문자열을 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : li
# (나): compile('카')

# %%
import bs4
import re
webPage = open('gsm_sample4.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_text_all= bsObject.findAll('li',string=re.compile('카'))
print(len(tag_text_all))

for tag_li in tag_text_all :
 print(tag_li.text)
# Out:
# 3
#  아메리카노
#  카페라떼
#  카푸치노

# %% [markdown]
# [코드 gsm 4-34] \[문제10] 웹소스의 \[고객센터] 문자열을 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : div
# (나) : cust

# %%
import bs4
import urllib.request

libraryUrl = "https://www.littlemom.co.kr:8443/sub/main.html"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'cust'})
print(tag , '\n')

tag_c = tag.find('h2').text
print(tag_c , '\n')
# Out:
# <div class="cust">
# <h2>고객센터</h2>
# <div class="cust_l">
# <div class="ctel"><span>1588-2989</span></div>
# <div class="ctime">
# <p>평일 09:00 ~ 17:30</p>
# <p>점심 12:30 ~ 13:30</p>
# <p>토,일 / 공휴일 휴무</p>
# <p>고객게시판 문의 빠른 답변</p>
# </div>
# <div class="cqna">
# <p><a class="custlink" href="02/01.html">고객게시판 바로가기</a></p>
# <p><a class="custlink" href="02/04.html">자주하는 질문</a></p>
# </div>
# </div>
# </div>
#
# 고객센터

# %% [markdown]
# [코드 gsm 4-35] \[문제11] 웹소스의 국민은행, 농협의 계좌번호와 \[인터넷뱅킹]의 문자열을 출력하도록 파이썬 코드의
# 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : class
# (나) : cbank

# %%
import bs4
import urllib.request

libraryUrl = "https://www.littlemom.co.kr:8443/sub/main.html"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'cbank'})
tag_c = tag.findAll('p')

for bank in tag_c :
  print(bank.text)
# Out:
# 국민 : 712401-01-436597  /  농협 : 335-0004-5182-63
#                     예금주 : (주)개똥이네
# 인터넷뱅킹

# %% [markdown]
# [코드 gsm 4-36] \[문제12] 웹소스의 국민은행, 신한은행,…등 8개의 은행이 출력하도록 파이썬 코드의 빈칸 답을 쓰시오.

# %% [markdown]
# (가) : ul
# (나) : li

# %%
import bs4
import urllib.request

libraryUrl = "https://www.littlemom.co.kr:8443/sub/main.html"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'cbank'})
tag_c = tag.find('ul')
tag_b = tag.findAll('li')

for bank in tag_b :
  print(bank.text)
# Out:
# 국민은행
# 신한은행
# 우리은행
# 외환은행
# 기업은행
# 하나은행
# 씨티은행
# 제일은행
# 농협
# 우체국

# %% [markdown]
# [코드 gsm 4-37] \[문제13] 웹소스의 \[내책팔기], \[방문매입], \[지역매장]의 문자열을 출력하도록 파이썬 코드의 빈칸 답을
# 쓰시오.

# %% [markdown]
# (가) : class
# (나) : mainTbanner

# %%
import bs4
import urllib.request
libraryUrl = "https://www.littlemom.co.kr:8443/sub/main.html"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'mainTbanner'})
tag_c = tag.find('ul')
tag_b = tag.findAll('li')

for bank in tag_b :
  print(bank.text)
# Out:
# 내책팔기
# 방문매입
# 지역매장

# %% [markdown]
# [추가 실습]

# %%
import bs4
import urllib.request
libraryUrl = "https://www.induk.ac.kr/KR/cms/frCmnCon/index.do?MENU_ID=3960"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'tit_St'})

for val in tag :
  print(val.text)
# Out:
# 꿈을 키우고 변화하라.
#
#
# 그리하면 세계가 당신을 환영할 것이다!

# %%
import bs4
import urllib.request
libraryUrl = "https://www.induk.ac.kr/KR/cms/frCmnCon/index.do?MENU_ID=3960"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'class':'cont_St mT0'})

for val in tag :
  print(val.text)
# Out:
# 홈페이지를 방문해주신 여러분 환영합니다. 우리 인덕대학교는 1972년 기독교 정신을 바탕으로 ‘손과 머리로, 무에서 유로’라는 창조 정신의 건학이념으로 가지고,인성과 지식을 갖춘 실천 인재를 양성코자 설립되었습니다.

# %%
import bs4
import re
import urllib.request

libraryUrl = "https://search.naver.com/search.naver?query=%EC%98%81%ED%99%94"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.findAll('a', {'class':'this_text _text'})
tag_a = bsObject.findAll('dl', {'class':'info_group type_visible'})

for val in tag :
  print(val.text)
for val in tag_a :
  print(val.text)
# Out:
# 베테랑2
# 비긴 어게인
# 에이리언: 로물루스
# 트랩
# 안녕, 할부지
# 사랑의 하츄핑
# 브레드이발소: 빵스타의 탄생
# 룩백
#  개봉 2024.09.13. 평점 6.61
#  재개봉 2024.09.18. 평점 9.12
#  개봉 2024.08.14. 평점 8.74
#  개봉 2024.09.18. 평점 6.28
#  개봉 2024.09.04. 평점 8.61
#  개봉 2024.08.07. 평점 8.72
#  개봉 2024.09.14. 평점 9.60
#  개봉 2024.09.05. 평점 9.15

# %%
import bs4
import re
import urllib.request

libraryUrl = "https://www.induk.ac.kr"

htmlObject = urllib.request.urlopen(libraryUrl)
webPage = htmlObject.read()

bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag_text_all= bsObject.findAll('span',string=re.compile('증명'))
print(len(tag_text_all))

for tag_li in tag_text_all :
 print(tag_li.text)
# Out:
# 1
# 증명발급안내
